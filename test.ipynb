# %%
import pandas as pd

# %%
a = pd.read_csv('data.csv')
a.head(5)
# Out:
#    STT   Mã sinh viên          Họ lót  Tên   Ngày sinh  Xem điểm  Lịch học  \
# 0    1  48.01.104.001           Lê Vỹ   An  13/05/2004  Xem điểm       NaN
# 1    2  48.01.104.004  Lê Nguyễn Tuấn  Anh  09/09/2004  Xem điểm       NaN
# 2    3  48.01.104.007       Tô Lê Vân  Anh  07/09/2004  Xem điểm       NaN
# 3    4  48.01.104.009     Trương Hồng  Anh  14/04/2004  Xem điểm       NaN
# 4    5  48.01.104.012        Tất Thái  Bảo  05/10/2004  Xem điểm       NaN
#
#    Thông tin  Lịch thi  Học phí
# 0        NaN       NaN      NaN
# 1        NaN       NaN      NaN
# 2        NaN       NaN      NaN
# 3        NaN       NaN      NaN
# 4        NaN       NaN      NaN

# %%
b = pd.read_csv('link.csv')
b.head(5)
# Out:
#                                             Xem điểm  \
# 0  https://online.hcmue.edu.vn/Portlets/Uis_Myspa...
# 1  https://online.hcmue.edu.vn/Portlets/Uis_Myspa...
# 2  https://online.hcmue.edu.vn/Portlets/Uis_Myspa...
# 3  https://online.hcmue.edu.vn/Portlets/Uis_Myspa...
# 4  https://online.hcmue.edu.vn/Portlets/Uis_Myspa...
#
#                                             Lịch học  \
# 0  https://online.hcmue.edu.vn/Print_.aspx?NH=202...
# 1  https://online.hcmue.edu.vn/Print_.aspx?NH=202...
# 2  https://online.hcmue.edu.vn/Print_.aspx?NH=202...
# 3  https://online.hcmue.edu.vn/Print_.aspx?NH=202...
# 4  https://online.hcmue.edu.vn/Print_.aspx?NH=202...
#
#                                            Thông tin  \
# 0  https://online.hcmue.edu.vn/Portlets/UIS_MySpa...
# 1  https://online.hcmue.edu.vn/Portlets/UIS_MySpa...
# 2  https://online.hcmue.edu.vn/Portlets/UIS_MySpa...
# 3  https://online.hcmue.edu.vn/Portlets/UIS_MySpa...
# ...

# %%
a.values[:,:5]
# Out:
# array([[1, '48.01.104.001', 'Lê Vỹ', 'An', '13/05/2004'],
#        [2, '48.01.104.004', 'Lê Nguyễn Tuấn', 'Anh', '09/09/2004'],
#        [3, '48.01.104.007', 'Tô Lê Vân', 'Anh', '07/09/2004'],
#        [4, '48.01.104.009', 'Trương Hồng', 'Anh', '14/04/2004'],
#        [5, '48.01.104.012', 'Tất Thái', 'Bảo', '05/10/2004'],
#        [6, '48.01.104.017', 'Nguyễn Thanh', 'Bình', '24/11/2004'],
#        [7, '48.01.104.021', 'Cao Thị Xuân', 'Đạt', '31/01/2004'],
#        [8, '48.01.104.022', 'Huỳnh Tấn', 'Đạt', '12/05/2004'],
#        [9, '48.01.104.028', 'Nguyễn Chấn Nam', 'Doanh', '27/01/2004'],
#        [10, '48.01.104.029', 'Nguyễn', 'Du', '23/09/2004'],
#        [11, '48.01.104.030', 'Nguyễn Trọng', 'Đức', '04/07/2004'],
#        [12, '48.01.104.034', 'Nguyễn Đức', 'Duy', '08/08/2004'],
#        [13, '48.01.104.036', 'Nguyễn Thị Mỹ', 'Duyên', '01/03/2004'],
#        [14, '48.01.104.039', 'Lê Thanh', 'Hải', '14/09/2004'],
# ...

# %%
pd.concat([a,b], axis=1)
# Out:
#     STT   Mã sinh viên               Họ lót    Tên   Ngày sinh  Xem điểm  \
# 0     1  48.01.104.001                Lê Vỹ     An  13/05/2004  Xem điểm
# 1     2  48.01.104.004       Lê Nguyễn Tuấn    Anh  09/09/2004  Xem điểm
# 2     3  48.01.104.007            Tô Lê Vân    Anh  07/09/2004  Xem điểm
# 3     4  48.01.104.009          Trương Hồng    Anh  14/04/2004  Xem điểm
# 4     5  48.01.104.012             Tất Thái    Bảo  05/10/2004  Xem điểm
# 5     6  48.01.104.017         Nguyễn Thanh   Bình  24/11/2004  Xem điểm
# 6     7  48.01.104.021         Cao Thị Xuân    Đạt  31/01/2004  Xem điểm
# 7     8  48.01.104.022            Huỳnh Tấn    Đạt  12/05/2004  Xem điểm
# 8     9  48.01.104.028      Nguyễn Chấn Nam  Doanh  27/01/2004  Xem điểm
# 9    10  48.01.104.029               Nguyễn     Du  23/09/2004  Xem điểm
# 10   11  48.01.104.030         Nguyễn Trọng    Đức  04/07/2004  Xem điểm
# 11   12  48.01.104.034           Nguyễn Đức    Duy  08/08/2004  Xem điểm
# ...
