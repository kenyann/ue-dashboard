# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
import pandas as pd

# %%
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)

driver = webdriver.Chrome(options=chrome_options)
driver.get("https://online.hcmue.edu.vn/")

login = driver.find_element(By.ID, 'lbtDangnhap')
login.click()

staff = driver.find_element(By.ID, 'ContentPlaceHolder1_ctl00_ctl00_rbtnStaff')
staff.click()

input_user = driver.find_element(
    By.ID, 'ContentPlaceHolder1_ctl00_ctl00_txtUserName')
input_password = driver.find_element(
    By.ID, 'ContentPlaceHolder1_ctl00_ctl00_txtPassword')

input_user.send_keys('minhlt_TCHC')
input_password.send_keys('minhlt_TCHC')

driver.find_element(By.ID, 'ContentPlaceHolder1_ctl00_ctl00_btLogin').click()
driver.get('https://online.hcmue.edu.vn/Portlets/Uis_Myspace/Professor/Marks.aspx?StudentID=44.01.104.072')

# %%
tbSource = driver.find_element(By.ID, 'tbSource')
tbodys = tbSource.find_elements(By.TAG_NAME, 'tbody')

# %%
data = []
for tbody in tbodys:
    table = tbody.find_elements(By.TAG_NAME, 'table')
    if len(table) == 1:
        rows = table[0].find_elements(By.TAG_NAME, 'tr')
        for row in rows[:-2]:
            cols = row.find_elements(By.TAG_NAME, 'td')
            data.append([col.text for col in cols])

# %%
col = ['STT',
 'Mã học phần',
 'Tên học phần',
 'Tín chỉ',
 'Loại môn học',
 'Điểm',
 'Điểm chữ',
 'Kết quả',
 'Chi tiết']

df = pd.DataFrame(data=data, columns=col)
df
# Out:
#     STT    Mã học phần                                       Tên học phần  \
# 0   STT    Mã học phần                                       Tên học phần
# 1     1   1811MILI2401   Đường lối quốc phòng và an ninh của Đảng Cộng...
# 2     2   1811MATH1002                                        Giải tích 1
# 3     3   1811PHYL2401          Giáo dục thể chất 1 (Thể dục - Điền kinh)
# 4     4   1811COMP1010                                   Lập trình cơ bản
# ..  ...            ...                                                ...
# 56  STT    Mã học phần                                       Tên học phần
# 57    1   2111COMP1046                              Các hệ cơ sở tri thức
# 58  STT    Mã học phần                                       Tên học phần
# 59    1   2121COMP1083                               Khóa luận tốt nghiệp
# 60    2   2121MILI2704          Kỹ thuật chiến đấu bộ binh và chiến thuật
#
#     Tín chỉ  Loại môn học   Điểm  Điểm chữ  Kết quả  Chi tiết
# 0   Tín chỉ  Loại môn học   Điểm  Điểm chữ  Kết quả  Chi tiết
# 1         2      Bắt Buộc   4.00         Ð           Chi tiết
# 2         3      Bắt Buộc   0.50        F+           Chi tiết
# 3         1       Tự Chọn   4.00         A           Chi tiết
# 4         3      Bắt Buộc   3.50        B+           Chi tiết
# ..      ...           ...    ...       ...      ...       ...
# 56  Tín chỉ  Loại môn học   Điểm  Điểm chữ  Kết quả  Chi tiết
# 57        3      Bắt Buộc   4.00         A           Chi tiết
# 58  Tín chỉ  Loại môn học   Điểm  Điểm chữ  Kết quả  Chi tiết
# 59        6       Tự Chọn   4.00         A           Chi tiết
# 60        4       Tự Chọn   4.00         Ð           Chi tiết
#
# [61 rows x 9 columns]

# %%
df[df.STT != 'STT']
# Out:
#    STT    Mã học phần                                       Tên học phần  \
# 1    1   1811MILI2401   Đường lối quốc phòng và an ninh của Đảng Cộng...
# 2    2   1811MATH1002                                        Giải tích 1
# 3    3   1811PHYL2401          Giáo dục thể chất 1 (Thể dục - Điền kinh)
# 4    4   1811COMP1010                                   Lập trình cơ bản
# 5    5   1811POLI1001   Những nguyên lý cơ bản của chủ nghĩa Mác – Lênin
# 6    6   1811ENGL2401                               Tiếng Anh học phần I
# 7    7       ENGL2401                               Tiếng Anh học phần I
# 8    8   1811TTTH1001                                    Tin học căn bản
# 9    9   1811MATH1010                                       Toán rời rạc
# 11   1   1821MATH1108                                  Đại số tuyến tính
# 12   2   1821PHYL2406               Giáo dục Thể chất 2 - Bơi lội cơ bản
# 13   3   1821COMP1017                          Lập trình hướng đối tượng
# 14   4   1821COMP1013                                 Lập trình nâng cao
# 15   5   1821COMP1412                                   Lý thuyết đồ thị
# 16   6   1821POLI1903                                Pháp luật đại cương
# 17   7   1821COMP1205                    Phương pháp nghiên cứu khoa học
# 18   8   1821COMP1502                   Quy hoạch tuyến tính và ứng dụng
# 19   9   1821POLI1003                               Tư tưởng Hồ Chí Minh
# 21   1   1831COMP1018                                      Cơ sở dữ liệu
# 22   2   1831MATH1002                                        Giải tích 1
# 24   1   1911COMP1016                                   Cấu trúc dữ liệu
# 25   2   1911POLI1002     Đường lối cách mạng của Đảng Cộng sản Việt Nam
# 26   3   1911PHYL2415             Giáo dục Thể chất 3 - Bơi lội nâng cao
# 27   4   1911MILI2404                Hiểu biết chung về quân, binh chủng
# 28   5   1911COMP1011                      Kiến trúc máy tính và hợp ngữ
# 29   6   1911COMP1207                      Phát triển ứng dụng giao diện
# 30   7       ENGL2402                              Tiếng Anh học phần II
# 31   8   1911COMP1501                      Xác suất thống kê và ứng dụng
# 33   1   1921MILI2402                     Công tác quốc phòng và an ninh
# 34   2   1921COMP1332                                       Hệ điều hành
# 35   3   1921COMP1044                        Nhập môn công nghệ phần mềm
# 36   4   1921COMP1015                             Nhập môn mạng máy tính
# 37   5   1921COMP1401                   Phân tích và thiết kế giải thuật
# 38   6   1921COMP1304          Phát triển ứng dụng trên thiết bị di động
# 39   7   1921COMP1303                            Phát triển ứng dụng Web
# 40   8       ENGL2403                             Tiếng Anh học phần III
# 42   1   2011COMP1047                                    Đồ hoạ máy tính
# 43   2   2011COMP1321                         Khai thác nội dung văn bản
# 44   3   2011COMP1326               Lắp ráp, cài đặt và bảo trì máy tính
# 45   4   2011COMP1319                          Lý thuyết số và logic học
# 46   5   2011COMP1317                              Nhận dạng và ứng dụng
# 47   6   2011COMP1314                                   Trí tuệ nhân tạo
# 48   7   2011COMP1050                                       Xử lý ảnh số
# 50   1   2021COMP1318                       Các phương pháp học thống kê
# 51   2   2021COMP1057                               Logic mờ và ứng dụng
# 52   3   2021COMP1052                                            Máy học
# 53   4   2021COMP1323                   Nhập môn xử lý ngôn ngữ tự nhiên
# 54   5   2021COMP1410                             Thực tập nghề nghiệp 1
# 55   6   2021COMP1411                             Thực tập nghề nghiệp 2
# 57   1   2111COMP1046                              Các hệ cơ sở tri thức
# 59   1   2121COMP1083                               Khóa luận tốt nghiệp
# 60   2   2121MILI2704          Kỹ thuật chiến đấu bộ binh và chiến thuật
#
#    Tín chỉ Loại môn học   Điểm Điểm chữ Kết quả  Chi tiết
# 1        2     Bắt Buộc   4.00        Ð          Chi tiết
# 2        3     Bắt Buộc   0.50       F+          Chi tiết
# 3        1      Tự Chọn   4.00        A          Chi tiết
# 4        3     Bắt Buộc   3.50       B+          Chi tiết
# 5        5     Bắt Buộc   2.50       C+          Chi tiết
# 6        4      Tự Chọn   3.50       B+          Chi tiết
# 7        4      Tự Chọn               M          Chi tiết
# 8        3     Bắt Buộc   3.50       B+          Chi tiết
# 9        2     Bắt Buộc   3.00        B          Chi tiết
# 11       3     Bắt Buộc   2.50       C+          Chi tiết
# 12       1      Tự Chọn   3.00        B          Chi tiết
# 13       3     Bắt Buộc   2.00        C          Chi tiết
# 14       3     Bắt Buộc   3.50       B+          Chi tiết
# 15       3     Bắt Buộc   4.00        A          Chi tiết
# 16       2     Bắt Buộc   4.00        A          Chi tiết
# 17       2     Bắt Buộc   4.00        A          Chi tiết
# 18       3     Bắt Buộc   2.50       C+          Chi tiết
# 19       2     Bắt Buộc   2.50       C+          Chi tiết
# 21       3     Bắt Buộc   3.50       B+          Chi tiết
# 22       3     Bắt Buộc   3.00        B          Chi tiết
# 24       3     Bắt Buộc   1.00        D          Chi tiết
# 25       3     Bắt Buộc   3.00        B          Chi tiết
# 26       1      Tự Chọn   4.00        A          Chi tiết
# 27       1     Bắt Buộc   4.00        Ð          Chi tiết
# 28       3     Bắt Buộc   3.00        B          Chi tiết
# 29       3     Bắt Buộc   4.00        A          Chi tiết
# 30       3      Tự Chọn               M          Chi tiết
# 31       3     Bắt Buộc   2.50       C+          Chi tiết
# 33       2     Bắt Buộc   4.00        Ð          Chi tiết
# 34       3     Bắt Buộc   4.00        A          Chi tiết
# 35       3      Tự Chọn   4.00        A          Chi tiết
# 36       3     Bắt Buộc   2.50       C+          Chi tiết
# 37       3     Bắt Buộc   2.50       C+          Chi tiết
# 38       3     Bắt Buộc   4.00        A          Chi tiết
# 39       3     Bắt Buộc   4.00        A          Chi tiết
# 40       3      Tự Chọn               M          Chi tiết
# 42       3      Tự Chọn   3.00        B          Chi tiết
# 43       3      Tự Chọn   4.00        A          Chi tiết
# 44       3      Tự Chọn   4.00        A          Chi tiết
# 45       3      Tự Chọn   2.50       C+          Chi tiết
# 46       3      Tự Chọn   4.00        A          Chi tiết
# 47       3     Bắt Buộc   3.50       B+          Chi tiết
# 48       3      Tự Chọn   4.00        A          Chi tiết
# 50       3      Tự Chọn   4.00        A          Chi tiết
# 51       3      Tự Chọn   4.00        A          Chi tiết
# 52       3      Tự Chọn   4.00        A          Chi tiết
# 53       3      Tự Chọn   4.00        A          Chi tiết
# 54       2     Bắt Buộc   4.00        A          Chi tiết
# 55       6     Bắt Buộc   4.00        A          Chi tiết
# 57       3     Bắt Buộc   4.00        A          Chi tiết
# 59       6      Tự Chọn   4.00        A          Chi tiết
# 60       4      Tự Chọn   4.00        Ð          Chi tiết
